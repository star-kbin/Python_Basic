# %% [markdown]
# **요약 (강사용 보충)**
#
# 리스트: 생성, 인덱싱, 슬라이싱, 반복, 변경 가능한(mutable) 성질과 실무 팁.
#
# ---

# %% [markdown]
# ### 리스트 자료형

# %%
odd = [1, 3, 5, 7, 9]

# %%
odd
# Out:
# [1, 3, 5, 7, 9]

# %%
a = []
b = [1, 2, 3]
c = ['Life', 'is', 'too', 'short']
d = [1, 2, 'Life', 'is']
e = [1, 2, ['Life', 'is']]

# %%
e
# Out:
# [1, 2, ['Life', 'is']]

# %%
f = list()

# %%
f
# Out:
# []

# %%
# 리스트 인덱싱

a = [1, 2, 3]
a
# Out:
# [1, 2, 3]

# %%
a[0]
# Out:
# 1

# %%
a[0] + a[2]
# Out:
# 4

# %%
a[-1]
# Out:
# 3

# %%
a = [1, 2, 3, ['a', 'b', 'c']]

# %%
a [0], a[-1], a[3]
# Out:
# (1, ['a', 'b', 'c'], ['a', 'b', 'c'])

# %%
a[-1][0]
# Out:
# 'a'

# %%
a[-1][2]
# Out:
# 'c'

# %%
# 리스트의 슬라이싱

a = [1, 2, 3, 4, 5]
a[0:2]
# Out:
# [1, 2]

# %%
a = "12345"
a[0:2]
# Out:
# '12'

# %%
a = [1, 2, 3, 4, 5]
b = a[:2]
c = a[2:]

# %%
b, c
# Out:
# ([1, 2], [3, 4, 5])

# %%
# 리스트 연산하기

a = [1, 2, 3]
b = [4, 5, 6]
a + b
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
# 리스트 반복하기

a = [1, 2, 3]
a * 3
# Out:
# [1, 2, 3, 1, 2, 3, 1, 2, 3]

# %%
# 리스트 길이 구하기

a = [1, 2, 3]
len(a)
# Out:
# 3

# %%
# 리스트 연산 오류

a = [1, 2, 3]
a[2] + "hi"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[25], line 4
#       1 # 리스트 연산 오류
#       2
#       3 a = [1, 2, 3]
# ----> 4 a[2] + "hi"
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
str(a[2]) + "hi"  # str() 함수를 이용하여 숫자를 문자열로 변환하여 연산하기
# Out:
# '3hi'

# %%
# 리스트의 값 수정하기

a = [1, 2, 3]
a[2] = 4
a
# Out:
# [1, 2, 4]

# %%
# del로 리스트 요소 삭제하기

a = [1, 2, 3]
del a[2]
a
# Out:
# [1, 2]

# %%
a = [1, 2, 3, 4]
del a[2:]
a
# Out:
# [1, 2]

# %%
# 리스트에 요소 추가하기

a = [1, 2, 3]
a.append(4)
a
# Out:
# [1, 2, 3, 4]

# %%
a.append([5, 6])
a
# Out:
# [1, 2, 3, 4, [5, 6]]

# %%
# 리스트 정렬

a = [1, 4, 3, 2]
a.sort()
a
# Out:
# [1, 2, 3, 4]

# %%
a = ['a', 'c', 'b']
a.sort()
a
# Out:
# ['a', 'b', 'c']

# %%
# 리스트 뒤집기

a = ['a', 'c', 'b']
a.reverse()
a
# Out:
# ['b', 'c', 'a']

# %%
# 인덱스 반환

a = [1, 2, 3]
a.index(3)
# Out:
# 2

# %%
a.index(1)
# Out:
# 0

# %%
a.index(4)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 a.index(4)
#
# ValueError: 4 is not in list

# %%
# 리스트에 요소 삽입

a = [1, 2, 3]
a.insert(0, 4) # insert(삽입할 위치, 삽입할 요소)
a
# Out:
# [4, 1, 2, 3]

# %%
a.insert(3, 5)
a
# Out:
# [4, 1, 2, 5, 3]

# %%
# 리스트 요소 제거

a = [1, 2, 3, 1, 2, 3]
a.remove(3) # 첫번째 요소를 제거한다.
a
# Out:
# [1, 2, 1, 2, 3]

# %%
a.remove(3)
a
# Out:
# [1, 2, 1, 2]

# %%
# 리스트 요소 꺼내기

a = [1, 2, 3]
a.pop()
# Out:
# 3

# %%
a
# Out:
# [1, 2]

# %%
# 리스트에 포함된 요소의 개수 세기

a = [1, 2, 3, 1]
a.count(1)
# Out:
# 2

# %%
# 리스트 확장

a = [1, 2, 3]
a.extend([4, 5])
a
# Out:
# [1, 2, 3, 4, 5]

# %%
b = [6, 7]
a.extend(b)
a
# Out:
# [1, 2, 3, 4, 5, 6, 7]

# %%
a = [1, 2, 3]
a += [4,5]
a
# Out:
# [1, 2, 3, 4, 5]
