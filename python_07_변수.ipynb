# %% [markdown]
# **요약 (강사용 보충)**
#
# 변수: 네이밍 규칙, 할당, 스코프(지역/전역) 기본, 할당시 복사/참조 차이.
#
# ---

# %% [markdown]
# ### 자료형의 값을 저장하는 공간, 변수

# %%
# 변수 예제 (C나 Java 같은 경우 변수를 만들때 자료형을 지정해야 한다.)

a = 1
b = "python"
c = [1, 2, 3]

# %%
# 변수명 규칙
# 1. 영문자, 숫자, 언더스코어(_)만 사용할 수 있다.
# 2. 숫자로 시작할 수 없다.
# 예약어는 사용할 수 없다.
# 대소문자를 구분한다.

# %%
# 올바른 변수명 예시

name = "홍길동"
age = 25
user_name = "gildong"
userName = "gildong"
_private = "비공개"
count1 = 10

# %%
# 잘못된 변수명 예시
# 1name = "홍길동"    # 숫자로 시작
# user-name = "홍길동"    #하이픈 사용
# if = 10             # 예약어 사용

# %% [markdown]
# ### 파이썬 예약어
#
# False, None, True, and, as, assert, break, class, continue, def,
# del, elif, else, except, finally, for, from, global, if, import,
# in, is, lambda, nonlocal, not, or, pass, raise, return, try,
# while, with, yield

# %%
# 변수란

a = [1, 2, 3]
id(a)      # 변수가 가리키는 메모리 주소
# Out:
# 2973460740928

# %%
# 리스트를 복사 할 때

a = [1, 2, 3]
b = a

# %%
id(a)
# Out:
# 2973461324736

# %%
id(b)
# Out:
# 2973461324736

# %%
a is b  # a와 b가 가리키는 객체가 같은가?
# Out:
# True

# %%
a[1] = 4
a
# Out:
# [1, 4, 3]

# %%
b
# Out:
# [1, 4, 3]

# %%
# b 변수를 생성할 때 a 변수의 값을 가져와 다른 주소를 가리키도록 만드는 방법

a = [1, 2, 3]
b = a[:]
a[1] = 4
a
# Out:
# [1, 4, 3]

# %%
b
# Out:
# [1, 2, 3]

# %%
a = [1, 2, 3]
b = a.copy()
a[1] = 4
a
# Out:
# [1, 4, 3]

# %%
b
# Out:
# [1, 2, 3]

# %%
# 변수를 만드는 여러가지 방법

a, b = ('python', 'life')
a
# Out:
# 'python'

# %%
b
# Out:
# 'life'

# %%
(a, b) = 'python', 'life'
a
# Out:
# 'python'

# %%
b
# Out:
# 'life'

# %%
[a, b] = ['python', 'life']
a
# Out:
# 'python'

# %%
b
# Out:
# 'life'

# %%
a = b = 'python'
a
# Out:
# 'python'

# %%
b
# Out:
# 'python'

# %%
a = 3
b = 5
a, b = b, a
a
# Out:
# 5

# %%
b
# Out:
# 3
